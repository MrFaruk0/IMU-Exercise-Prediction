# %%
import os
import sys
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath(".."))
from src.loader import RecGym_DATA

# %%
dataset = RecGym_DATA(
    root_path="../data/RGDT",
    window_size=4,
    overlap_size=2,
)
# Out:
#  ----------------------- load all the data -------------------
# (117582, 80, 7)
# (117582,)

# %%
print("Toplam pencere sayısı:", len(dataset))
# Out:
# Toplam pencere sayısı: 117582

# %%
sample, label = dataset[0]
print("Sample shape:", sample.shape)   # (window_size*20, 7)
print("Label:", label)
# Out:
# Sample shape: (80, 7)
# Label: 6

# %%
plt.figure(figsize=(10,5))
plt.plot(sample[:,0], label="A_x")
plt.plot(sample[:,1], label="A_y")
plt.plot(sample[:,2], label="A_z")
plt.title(f"Egzersiz label={label}")
plt.legend()
plt.show()
